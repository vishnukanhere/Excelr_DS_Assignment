# %% [raw]
# # Prepare a prediction model for profit of 50_startups data.
# Do transformations for getting better predictions of profit and
# make a table containing R^2 value for each prepared model.
#
# R&D Spend -- Research and devolop spend in the past few years
# Administration -- spend on administration in the past few years
# Marketing Spend -- spend on Marketing in the past few years
# State -- states from which data is collected
# Profit  -- profit of each state in the past few years

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\YASH COMPUTER\\Downloads\\50_Startups.csv")
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
data=data.rename({'R&D Spend': 'RDS', 'Administration' : 'Admin', 'Marketing Spend': 'MKTS'},axis=1)
data
# Out:
#           RDS      Admin       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
data.corr()
# Out:
# C:\Users\YASH COMPUTER\AppData\Local\Temp\ipykernel_7860\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#              RDS     Admin      MKTS    Profit
# RDS     1.000000  0.241955  0.724248  0.972900
# Admin   0.241955  1.000000 -0.032154  0.200717
# MKTS    0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\YASH COMPUTER\AppData\Local\Temp\ipykernel_7860\1428011469.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
data=pd.get_dummies(data, columns = ['State'])
data
# Out:
#           RDS      Admin       MKTS     Profit  State_California  \
# 0   165349.20  136897.80  471784.10  192261.83                 0
# 1   162597.70  151377.59  443898.53  191792.06                 1
# 2   153441.51  101145.55  407934.54  191050.39                 0
# 3   144372.41  118671.85  383199.62  182901.99                 0
# 4   142107.34   91391.77  366168.42  166187.94                 0
# 5   131876.90   99814.71  362861.36  156991.12                 0
# 6   134615.46  147198.87  127716.82  156122.51                 1
# 7   130298.13  145530.06  323876.68  155752.60                 0
# 8   120542.52  148718.95  311613.29  152211.77                 0
# 9   123334.88  108679.17  304981.62  149759.96                 1
# 10  101913.08  110594.11  229160.95  146121.95                 0
# 11  100671.96   91790.61  249744.55  144259.40                 1
# 12   93863.75  127320.38  249839.44  141585.52                 0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df1=scaler.fit_transform(data)
scaled_df=pd.DataFrame(df1,columns=data.columns)
scaled_df.head()
# Out:
#         RDS     Admin      MKTS    Profit  State_California  State_Florida  \
# 0  1.000000  0.651744  1.000000  1.000000               0.0            0.0
# 1  0.983359  0.761972  0.940893  0.997355               1.0            0.0
# 2  0.927985  0.379579  0.864664  0.993178               0.0            1.0
# 3  0.873136  0.512998  0.812235  0.947292               0.0            0.0
# 4  0.859438  0.305328  0.776136  0.853171               0.0            1.0
#
#    State_New York
# 0             1.0
# 1             0.0
# 2             0.0
# 3             1.0
# 4             0.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df2 = scaler.fit_transform(data)
scaled_df = pd.DataFrame(df2, columns = data.columns)
scaled_df.head()
# Out:
#         RDS     Admin      MKTS    Profit  State_California  State_Florida  \
# 0  2.016411  0.560753  2.153943  2.011203         -0.717741      -0.685994
# 1  1.955860  1.082807  1.923600  1.999430          1.393261      -0.685994
# 2  1.754364 -0.728257  1.626528  1.980842         -0.717741       1.457738
# 3  1.554784 -0.096365  1.422210  1.776627         -0.717741      -0.685994
# 4  1.504937 -1.079919  1.281528  1.357740         -0.717741       1.457738
#
#    State_New York
# 0        1.393261
# 1       -0.717741
# 2       -0.717741
# 3        1.393261
# 4       -0.717741

# %%
import statsmodels.formula.api as smf
model = smf.ols(formula ='Profit~RDS+Admin+MKTS',data = data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Tue, 11 Jul 2023   Prob (F-statistic):           4.53e-30
# Time:                        11:59:06   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
model.rsquared
# Out:
# 0.9507459940683246

# %%
# Since the p value for Administration and Marketing Spend is > 0.05 build simple linear regression and multi linear regress

# %%
data_Admin = smf.ols('Profit~Admin',data).fit()
data_Admin.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Tue, 11 Jul 2023   Prob (F-statistic):              0.162
# Time:                        12:00:16   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.697e+04   2.53e+04      3.040      0.004    2.61e+04    1.28e+05
# ...

# %%
data_MKTS = smf.ols('Profit~MKTS',data).fit()
data_MKTS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Tue, 11 Jul 2023   Prob (F-statistic):           4.38e-10
# Time:                        12:01:09   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept       6e+04   7684.530      7.808      0.000    4.46e+04    7.55e+04
# ...

# %%
rsq_RDS = smf.ols('RDS~Admin+MKTS', data).fit().rsquared
vif_RDS = 1/(1-rsq_RDS)

rsq_Admin = smf.ols('Admin~RDS+MKTS', data).fit().rsquared
vif_Admin = 1/(1-rsq_Admin)

rsq_MKTS = smf.ols('MKTS~RDS+Admin', data).fit().rsquared
vif_MKTS = 1/(1-rsq_MKTS)

d1 = {'variables' :['RDS', 'Admin', 'MKTS'], 'VIF': [vif_RDS, vif_Admin, vif_MKTS]}
Vif_frame = pd.DataFrame(d1)
Vif_frame
# Out:
#   variables       VIF
# 0       RDS  2.468903
# 1     Admin  1.175091
# 2      MKTS  2.326773

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Nomral Q-Q plot of residuals")
plt.show()

# %%
np.where(model.resid>10)
# Out:
# (array([ 1,  2,  3,  8, 10, 11, 12, 13, 16, 19, 20, 25, 28, 30, 34, 35, 36,
#         37, 38, 40, 41, 42, 43, 44, 45], dtype=int64),)

# %%
def get_standardize_values( vals): 
  return (vals - vals.mean())/vals.std()
plt.scatter(get_standardize_values(model.fittedvalues), get_standardize_values(model.resid))
plt.ylabel('Standardize Residual values')
plt.xlabel('Standardize Fitted values')
plt.title('Residual Plot')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "RDS", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Admin", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "MKTS", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance
fig = plt.subplots(figsize=(20,8))
plt.stem(np.arange(len(data)), np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c), np.max(c))
# Out:
# (49, 0.28808229275432634)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = data.shape[1]
n = data.shape[0]
leverage_cutoff = 3*(k+1)/n
leverage_cutoff
# Out:
# 0.48

# %%
model=smf.ols(formula ='Profit~RDS+Admin+MKTS', data = data).fit()
(model.rsquared,model.aic)
# Out:
# (0.9507459940683246, 1058.7714985998055)

# %%
data[data.index.isin([49])]
# Out:
#     RDS     Admin      MKTS   Profit  State_California  State_Florida  \
# 49  0.0  116983.8  45173.06  14681.4                 1              0
#
#     State_New York
# 49               0

# %%
data1=data.drop(data.index[[49]],axis=0).reset_index(drop=True)
data1
# Out:
#           RDS      Admin       MKTS     Profit  State_California  \
# 0   165349.20  136897.80  471784.10  192261.83                 0
# 1   162597.70  151377.59  443898.53  191792.06                 1
# 2   153441.51  101145.55  407934.54  191050.39                 0
# 3   144372.41  118671.85  383199.62  182901.99                 0
# 4   142107.34   91391.77  366168.42  166187.94                 0
# 5   131876.90   99814.71  362861.36  156991.12                 0
# 6   134615.46  147198.87  127716.82  156122.51                 1
# 7   130298.13  145530.06  323876.68  155752.60                 0
# 8   120542.52  148718.95  311613.29  152211.77                 0
# 9   123334.88  108679.17  304981.62  149759.96                 1
# 10  101913.08  110594.11  229160.95  146121.95                 0
# 11  100671.96   91790.61  249744.55  144259.40                 1
# 12   93863.75  127320.38  249839.44  141585.52                 0
# ...

# %%
new_data=pd.DataFrame({'RDS':40, 'Admin':95, 'MKTS':102},index=[0])
new_data
# Out:
#    RDS  Admin  MKTS
# 0   40     95   102

# %%
final_model=smf.ols(formula ='Profit~RDS+Admin+MKTS', data = data).fit()
(model.rsquared,model.aic)
# Out:
# (0.9507459940683246, 1058.7714985998055)

# %%
final_model.predict(new_data)
# Out:
# 0    50154.651337
# dtype: float64

# %%
predictions=final_model.predict(data1)
predictions
# Out:
# 0     192521.252890
# 1     189156.768232
# 2     182147.279096
# 3     173696.700026
# 4     172139.514183
# 5     163580.780571
# 6     158114.096669
# 7     160021.363048
# 8     151741.699699
# 9     154884.684110
# 10    135509.016367
# 11    135573.712961
# 12    129138.054182
# 13    127487.991663
# 14    149548.646335
# 15    146235.159985
# 16    116915.405401
# 17    130192.447208
# 18    129014.226806
# 19    115635.216367
# 20    116639.669231
# 21    117319.451640
# 22    114706.981717
# 23    109996.615221
# 24    113362.966113
# 25    102237.725065
# 26    110600.575350
# 27    114408.071457
# 28    101660.026005
# 29    101794.983452
# 30     99452.372936
# 31     97687.856276
# 32     99001.328985
# 33     97915.007805
# 34     89039.273741
# 35     90511.599568
# 36     75286.174585
# 37     89619.537708
# 38     69697.430648
# 39     83729.011977
# 40     74815.953991
# 41     74802.556239
# 42     70620.411821
# 43     60167.039963
# 44     64611.354916
# ...

# %%
model_final=smf.ols("Profit~RDS+Admin+MKTS",data=data1).fit()
model_final

# %%
while model_final.rsquared < 0.99:
    for c in [np.max(c)>1]:
        model_final=smf.ols("Profit~RDS+Admin+MKTS",data=data1).fit()
        (c,_)=model_final.get_influence().cooks_distance
        c
        np.argmax(c) , np.max(c)
        data1=data1.drop(data1.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
        data1
    else:
        final_model=smf.ols("Profit~RDS+Admin+MKTS",data=data1).fit()
        final_model.rsquared , final_model.aic
        print("Thus model accuracy is improved to",final_model)
# Out:
# Thus model accuracy is improved to <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000021674AE2140>
# Thus model accuracy is improved to <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000021674BB6170>
# Thus model accuracy is improved to <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000021674B36D10>
# Thus model accuracy is improved to <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000021674B37730>
# Thus model accuracy is improved to <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000021674B37460>
# Thus model accuracy is improved to <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000021674B36E90>
# Thus model accuracy is improved to <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000021674B35C90>
# ...

# %%
model.predict(new_data)
# Out:
# 0    50154.651337
# dtype: float64

# %%
profit_pred = 0.8057*40 + 0.0268*95 + 0.0272*102 + 5.012e+04
profit_pred
# Out:
# 50157.5484

# %%
pred_y=model.predict(data1)
pred_y
# Out:
# 0     172139.514183
# 1     163580.780571
# 2     160021.363048
# 3     151741.699699
# 4     154884.684110
# 5     127487.991663
# 6     130192.447208
# 7     129014.226806
# 8     116639.669231
# 9     109996.615221
# 10    113362.966113
# 11    102237.725065
# 12    110600.575350
# 13    101660.026005
# 14    101794.983452
# 15     99452.372936
# 16     97687.856276
# 17     99001.328985
# 18     97915.007805
# 19     89039.273741
# 20     90511.599568
# 21     89619.537708
# 22     83729.011977
# 23     74815.953991
# 24     74802.556239
# 25     70620.411821
# 26     64611.354916
# dtype: float64

# %%
d2={'Prepared_Models':['model','final_model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#   Prepared_Models  Rsquared
# 0           model  0.950746
# 1     final_model  0.988276
